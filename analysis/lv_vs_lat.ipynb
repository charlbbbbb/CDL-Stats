# %%
from cdl_helper import head_to_head, read_in_all_matches

import matplotlib.pyplot as plt
import pandas as pd

df = read_in_all_matches()
df.sample(5)
# Out:
#               gameMap       gameMode   id  programId firstName  lastName  \
# 7   Al Bagra Fortress  CDL Hardpoint  266          2    Travis   McCloud
# 28   Breenbergh Hotel  CDL Hardpoint   51          2    Cuyler   Garland
# 12  Al Bagra Fortress        CDL SnD   51          2    Cuyler   Garland
# 18   Breenbergh Hotel    CDL Control  225          2  Makenzie    Kelley
# 29            Embassy  CDL Hardpoint  117          2      Colt  McLendon
#
#       alias                                           headshot  \
# 7   Neptune  https://www.callofduty.com/content/dam/activis...
# 28     Huke  https://www.callofduty.com/content/dam/activis...
# 12     Huke  https://www.callofduty.com/content/dam/activis...
# 18     Mack  https://www.callofduty.com/content/dam/activis...
# 29    Havok  https://www.callofduty.com/content/dam/activis...
#
#                                  socialNetworkHandles  averageSpeed  ...  \
# ...

# %% [markdown]
# I will remove the players who are not on the current starting rosters

# %%
df = df[~df['alias'].isin(['Prolute', 'Capsidal'])]

# %%
fig = plt.figure(figsize=(14, 18))
((ax3, ax4),
 (ax5, ax6),
 (ax7, ax8)) = fig.subplots(ncols=2, nrows=3)

head_to_head(df, 'LV', 'LAT', 'kd', "Vegas Legion kd vs Los Angeles Thieves compared to vs rest of league",ax3, gamemode='CDL Hardpoint')
head_to_head(df, 'LAT', 'LV', 'kd', "Los Angeles Thieves kd vs Vegas Legion compared to vs rest of league",ax4, gamemode='CDL Hardpoint')
head_to_head(df, 'LV', 'LAT', 'totalDamageDealt', "Vegas Legion damage vs Los Angeles Thieves compared to vs rest of league",ax5, gamemode='CDL Hardpoint')
head_to_head(df, 'LAT', 'LV', 'totalDamageDealt', "Los Angeles Thieves damage vs Vegas Legion compared to vs rest of league",ax6, gamemode='CDL Hardpoint')
head_to_head(df, 'LV', 'LAT', 'accuracy', "Vegas Legion accuracy vs Los Angeles Thieves compared to vs rest of league",ax7, gamemode='CDL Hardpoint')
head_to_head(df, 'LAT', 'LV', 'accuracy', "Los Angeles Thieves accuracy vs Vegas Legion compared to vs rest of league",ax8, gamemode='CDL Hardpoint')

fig.suptitle("Vegas Legion And Los Angeles Thieves Head to Head Performances (Hardpoint)");

# %%
fig = plt.figure(figsize=(14, 18))
((ax3, ax4),
 (ax5, ax6),
 (ax7, ax8)) = fig.subplots(ncols=2, nrows=3)

head_to_head(df, 'LV', 'LAT', 'kd', "Vegas Legion kd vs Los Angeles Thieves compared to vs rest of league",ax3, gamemode='CDL SnD')
head_to_head(df, 'LAT', 'LV', 'kd', "Los Angeles Thieves kd vs Vegas Legion compared to vs rest of league",ax4, gamemode='CDL SnD')
head_to_head(df, 'LV', 'LAT', 'totalDamageDealt', "Vegas Legion damage vs Los Angeles Thieves compared to vs rest of league",ax5, gamemode='CDL SnD')
head_to_head(df, 'LAT', 'LV', 'totalDamageDealt', "Los Angeles Thieves damage vs Vegas Legion compared to vs rest of league",ax6, gamemode='CDL SnD')
head_to_head(df, 'LV', 'LAT', 'accuracy', "Vegas Legion accuracy accuracy vs Los Angeles Thieves compared to vs rest of league",ax7, gamemode='CDL SnD')
head_to_head(df, 'LAT', 'LV', 'accuracy', "Los Angeles Thieves accuracy vs Vegas Legion compared to vs rest of league",ax8, gamemode='CDL SnD')

fig.suptitle("Vegas Legion And Los Angeles Thieves Head to Head Performances (SnD)");

# %%
fig = plt.figure(figsize=(14, 18))
((ax3, ax4),
 (ax5, ax6),
 (ax7, ax8)) = fig.subplots(ncols=2, nrows=3)

head_to_head(df, 'LV', 'LAT', 'kd', "Vegas Legion kd vs Los Angeles Thieves compared to vs rest of league",ax3, gamemode='CDL Control')
head_to_head(df, 'LAT', 'LV', 'kd', "Los Angeles Thieves kd vs Vegas Legion compared to vs rest of league",ax4, gamemode='CDL Control')
head_to_head(df, 'LV', 'LAT', 'totalDamageDealt', "Vegas Legion damage vs Los Angeles Thieves compared to vs rest of league",ax5, gamemode='CDL Control')
head_to_head(df, 'LAT', 'LV', 'totalDamageDealt', "Los Angeles Thieves damage vs Vegas Legion compared to vs rest of league",ax6, gamemode='CDL Control')
head_to_head(df, 'LV', 'LAT', 'accuracy', "Vegas Legion accuracy accuracy vs Los Angeles Thieves compared to vs rest of league",ax7, gamemode='CDL Control')
head_to_head(df, 'LAT', 'LV', 'accuracy', "Los Angeles Thieves accuracy vs Vegas Legion compared to vs rest of league",ax8, gamemode='CDL Control')

fig.suptitle("Vegas Legion And Los Angeles Thieves Head to Head Performances (Control)");
